# %% [markdown]
# # Probability Distribution Problems

# %% [markdown]
# **Binomial Distribution**
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either Head or Tails.

# %%
# Probability functions, density and distribution

def dbinom(x,size,prob=0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.pmf(k=x,n=size,p=prob,loc=0)
    return result

def pbinom(q,size,prob=0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.cdf(k=q,n=size,p=prob,loc=0)
    return result

def qbinom(p, size, prob=0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.ppf(q=p,n=size,p=prob,loc=0)
    return result

def rbinom(n,size,prob=0.5):
    """
    Generates random variables from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.rvs(n=size,p=prob,size=n)
    return result

# %%
dbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) takes the value 2,
pbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) will take a value less than 2
qbinom(0.9, size = 10, prob = 0.2) # what value of a binomial (10,0.2) has a cumulative probability of 0.9?
rbinom(2000, size = 10, prob = 0.2) # generate 2000 random values from a binomial distribution (10,0.2)
# Out:
# array([1, 1, 1, ..., 1, 4, 2])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Discrete distributions
xs = np.arange( 1, 11 )
ys = dbinom(xs,size=10,prob=0.5) # compute the shape of the distribution
plt.plot( xs, ys, 'o' )   # plot circles...
plt.vlines( xs, 0, ys )   # ...and lines
plt.ylim( bottom=0 )      # ensure sensible bottom border
plt.title('Probability function binomial distribution')
plt.show()

# %% [markdown]
# Exercise 1: Create the same functions but for the normal and uniform distribution.

# %%
#Code here
import numpy as np
import matplotlib.pyplot as plt
def dnorm(x,mean=0,sd =1):
    """
    Calculates the density of the Normal distribution
    """
    from scipy.stats import norm
    result=norm.pdf(x,loc=mean,scale=sd)
    return result

def pnorm(q,mean=0,sd=1):
    """
    Calculates the cumulative of the normal distribution
    """
    from scipy.stats import norm
    result=norm.cdf(x=q,loc=mean,scale=sd)
    return result

def qnorm(p,mean=0,sd=1):
    """
    Calculates the quantile function of the normal distribution
    """
    from scipy.stats import norm
    result=norm.ppf(q=p,loc=mean,scale=sd)
    return result

def rnorm(n,mean=0,sd=1):
    """
    Generates random variables from the normal distribution
    """
    from scipy.stats import norm
    result=norm.rvs(size=n,loc=mean,scale=sd)
    return result

# %%
# Continuous distributions
x = np.arange(-5,5,0.1)
plt.plot(x,dnorm(x,mean=0,sd=1))

# %%
dnorm(5,0,1)
# Out:
# 1.4867195147342979e-06

# %%
 pnorm(5,0,1)
# Out:
# 0.9999997133484281

# %%
qnorm(5,0,1)
# Out:
# nan

# %%
rnorm(1,0,1)
# Out:
# array([-1.84711017])

# %%
x = np.arange(-5,5,0.1)
plt.plot(x,dnorm(x,mean=0,sd=1))

# %%
x = np.arange(-5,5,0.1)
plt.plot(x,pnorm(x,mean=0,sd=1))

# %%
x = np.arange(-5,5,0.1)
plt.plot(x,qnorm(x,mean=0,sd=1))

# %%
x = np.arange(-5,5,0.1)
plt.plot(x,rnorm(x,mean=0,sd=1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb Cell 16' in <cell line: 2>()
#       <a href='vscode-notebook-cell://marfurt1-probabilitydis-9mphpok6257.ws-us46.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#ch0000017vscode-remote?line=0'>1</a> x = np.arange(-5,5,0.1)
# ----> <a href='vscode-notebook-cell://marfurt1-probabilitydis-9mphpok6257.ws-us46.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#ch0000017vscode-remote?line=1'>2</a> plt.plot(x,rnorm(x,mean=0,sd=1))
#
# /workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb Cell 7' in rnorm(n, mean, sd)
#      <a href='vscode-notebook-cell://marfurt1-probabilitydis-9mphpok6257.ws-us46.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#ch0000006vscode-remote?line=28'>29</a> """
#      <a href='vscode-notebook-cell://marfurt1-probabilitydis-9mphpok6257.ws-us46.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#ch0000006vscode-remote?line=29'>30</a> Generates random variables from the normal distribution
#      <a href='vscode-notebook-cell://marfurt1-probabilitydis-9mphpok6257.ws-us46.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#ch0000006vscode-remote?line=30'>31</a> """
#      <a href='vscode-notebook-cell://marfurt1-probabilitydis-9mphpok6257.ws-us46.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#ch0000006vscode-remote?line=31'>32</a> from scipy.stats import norm
# ---> <a href='vscode-notebook-cell://marfurt1-probabilitydis-9mphpok6257.ws-us46.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#ch0000006vscode-remote?line=32'>33</a> result=norm.rvs(size=n,loc=mean,scale=sd)
#      <a href='vscode-notebook-cell://marfurt1-probabilitydis-9mphpok6257.ws-us46.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#ch0000006vscode-remote?line=33'>34</a> return result
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1093, in rv_generic.rvs(self, *args, **kwds)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py?line=1090'>1091</a>     vals = self._rvs(*args)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py?line=1091'>1092</a> else:
# -> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py?line=1092'>1093</a>     vals = self._rvs(*args, size=size, random_state=random_state)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py?line=1094'>1095</a> vals = vals * scale + loc
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py?line=1096'>1097</a> # do not forget to restore the _random_state
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:306, in norm_gen._rvs(self, size, random_state)
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py?line=304'>305</a> def _rvs(self, size=None, random_state=None):
# --> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py?line=305'>306</a>     return random_state.standard_normal(size)
#
# File mtrand.pyx:1403, in numpy.random.mtrand.RandomState.standard_normal()
#
# File _common.pyx:615, in numpy.random._common.cont()
#
# ValueError: maximum supported dimension for an ndarray is 32, found 100

# %%
from scipy.stats import uniform



#creating an array of values between
#-5 to 5 with a difference of 0.1
x = np.arange(-5, 5, 0.1)
   
y = uniform.pdf(x, 0, 5)
   
plt.plot(x, y) 
plt.show()
